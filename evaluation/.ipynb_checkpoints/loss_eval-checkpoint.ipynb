# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.image as img
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
# %matplotlib inline

# %%
imgname = '890.jpg'
infold = '../outputs/test/images/input/'
otfold = '../outputs/test/images/output/'
trfold = '../outputs/test/images/target/'

# %%
temp_in = img.imread(''.join((infold, imgname)))
temp_out = img.imread(''.join((otfold, imgname)))
temp_tar = img.imread(''.join((trfold, imgname)))

temp_noise = new_in - new_tar
temp_diff  = new_out - new_tar
temp_remove= new_out - new_in
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a0e01abf4777> in <module>()
#       3 temp_tar = img.imread(''.join((trfold, imgname)))
#       4
# ----> 5 temp_noise = new_in - new_tar
#       6 temp_diff  = new_out - new_tar
#       7 temp_remove= new_out - new_in
#
# NameError: name 'new_in' is not defined

# %%
f, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharex='col', sharey='row', figsize=(15,10))

ax1.imshow(temp_tar, cmap='Greys')
ax1.set_title('Groundtruth')
ax2.imshow(temp_in, cmap='Greys')
ax2.set_title('Network Input')
ax3.imshow(temp_out, cmap='Greys')
ax3.set_title('Network Output')
ax4.imshow(temp_noise, cmap='Greys')
ax4.set_title('Input - Groundtruth')
ax5.imshow(temp_diff, cmap='Greys')
ax5.set_title('Output - Groundtruth')
ax6.imshow(temp_remove, cmap='Greys')
ax6.set_title('Output - Input')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-95d0194ed283> in <module>()
#       7 ax3.imshow(temp_out, cmap='Greys')
#       8 ax3.set_title('Network Output')
# ----> 9 ax4.imshow(temp_noise, cmap='Greys')
#      10 ax4.set_title('Input - Groundtruth')
#      11 ax5.imshow(temp_diff, cmap='Greys')
#
# NameError: name 'temp_noise' is not defined

# %%
# %%time

loss = lambda target, output : np.sum(abs(output - target))

xlate_range = 800

scale_range = 400
scale_step  = .1

err_surf = np.zeros((xlate_range, scale_range))

for i in range(xlate_range):
    for j in range(scale_range):
        shifted = (temp_out - xlate_range/2 + i) * (j - scale_range/2) * scale_step
        err_surf[i,j] = loss(temp_tar, shifted)
# Out:
# CPU times: user 5min 41s, sys: 12 ms, total: 5min 41s
# Wall time: 5min 41s

# %%
plt.imshow(err_surf)
plt.colorbar()
plt.show()

# %%
err_surf.min()
# Out:
# 754793.09999999998

# %%
np.where(err_surf==err_surf.min())
# Out:
# (array([395]), array([211]))

# %%
err_surf[395,211]
# Out:
# 754793.09999999998

# %%
shifted = (temp_out - xlate_range/2 + 395) * (211 - scale_range/2) * scale_step

# %%
plt.imshow(shifted)
plt.show()
